# %% [markdown]
# <a href="https://colab.research.google.com/github/saturnsz/DataScience4/blob/main/student1(week4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/student_scores.csv")
df = df.dropna()
df
# Out:
#     student_id                 name  major01  major02  project  final
# 0    120060258        Mohamed Salah     0.25     0.00     0.00   13.0
# 2    211210095         Ahmed Assiri    13.25    14.60    16.25   24.0
# 3    212110756      Abdullah Ahmari     5.91     1.25     5.00    7.0
# 7    213110926           Anas Karim    16.00    13.50    16.67   23.0
# 8    213110964         Mahmoud Adel    10.00     6.30    11.67   17.0
# 10   213111128  Abdelhalim Mohanned    15.52    11.30    13.30   14.0
# 11   213111284         Khaled Majid    19.00    17.25    18.67   37.0
# 12   213254033             Saad Ali    20.00    18.80    18.67    3.0

# %%
display(df)
# Out:
#     student_id                 name  major01  major02  project  final
# 0    120060258        Mohamed Salah     0.25     0.00     0.00   13.0
# 2    211210095         Ahmed Assiri    13.25    14.60    16.25   24.0
# 3    212110756      Abdullah Ahmari     5.91     1.25     5.00    7.0
# 7    213110926           Anas Karim    16.00    13.50    16.67   23.0
# 8    213110964         Mahmoud Adel    10.00     6.30    11.67   17.0
# 10   213111128  Abdelhalim Mohanned    15.52    11.30    13.30   14.0
# 11   213111284         Khaled Majid    19.00    17.25    18.67   37.0
# 12   213254033             Saad Ali    20.00    18.80    18.67    3.0

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
# ambil hanya kolom student_id, name, dan final
example_df = df[['student_id','name','final']]

print('Example:')
example_df
# Out:
# Example:
#     student_id                 name  final
# 0    120060258        Mohamed Salah   13.0
# 2    211210095         Ahmed Assiri   24.0
# 3    212110756      Abdullah Ahmari    7.0
# 7    213110926           Anas Karim   23.0
# 8    213110964         Mahmoud Adel   17.0
# 10   213111128  Abdelhalim Mohanned   14.0
# 11   213111284         Khaled Majid   37.0
# 12   213254033             Saad Ali    3.0

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
# ambil hanya kolom student_id, major01, major02
example_df = df[['student_id','major01','major02']]

print('example:')
example_df
# Out:
# example:
#     student_id  major01  major02
# 0    120060258     0.25     0.00
# 2    211210095    13.25    14.60
# 3    212110756     5.91     1.25
# 7    213110926    16.00    13.50
# 8    213110964    10.00     6.30
# 10   213111128    15.52    11.30
# 11   213111284    19.00    17.25
# 12   213254033    20.00    18.80

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
# filter data sesuai yang tampil di tabel
filtered_df = df[df['student_id'].isin([212110889, 213111128, 213210082])][
    ['student_id','name','major01','major02','project','final']
]

filtered_df
# Out:
#     student_id                 name  major01  major02  project  final
# 10   213111128  Abdelhalim Mohanned    15.52     11.3     13.3   14.0

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
filtered_df = df[df['major01'].notna()][
    ['student_id','name','major01','major02','project','final']
]

#filtered_df2 = df[df['major02'].notna()][
#    ['student_id','name','major01','major02','project','final']
#]

filtered_df
# Out:
#     student_id                 name  major01  major02  project  final
# 0    120060258        Mohamed Salah     0.25     0.00     0.00   13.0
# 2    211210095         Ahmed Assiri    13.25    14.60    16.25   24.0
# 3    212110756      Abdullah Ahmari     5.91     1.25     5.00    7.0
# 7    213110926           Anas Karim    16.00    13.50    16.67   23.0
# 8    213110964         Mahmoud Adel    10.00     6.30    11.67   17.0
# 10   213111128  Abdelhalim Mohanned    15.52    11.30    13.30   14.0
# 11   213111284         Khaled Majid    19.00    17.25    18.67   37.0
# 12   213254033             Saad Ali    20.00    18.80    18.67    3.0

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
# filter sesuai table
# ambil hanya baris yang memiliki nilai di kolom major01 (tidak NaN)
# dan tampilkan kolom sesuai contoh
filtered_df = df[df['major01'].notna()][
    ['student_id','name','major01','major02','project','final']
]

print('filtered table (major01, major02, project, final:)')
filtered_df
# Out:
# filtered table (major01, major02, project, final:)
#     student_id                 name  major01  major02  project  final
# 0    120060258        Mohamed Salah     0.25     0.00     0.00   13.0
# 2    211210095         Ahmed Assiri    13.25    14.60    16.25   24.0
# 3    212110756      Abdullah Ahmari     5.91     1.25     5.00    7.0
# 7    213110926           Anas Karim    16.00    13.50    16.67   23.0
# 8    213110964         Mahmoud Adel    10.00     6.30    11.67   17.0
# 10   213111128  Abdelhalim Mohanned    15.52    11.30    13.30   14.0
# 11   213111284         Khaled Majid    19.00    17.25    18.67   37.0
# 12   213254033             Saad Ali    20.00    18.80    18.67    3.0

# %% [markdown]
# df['major01'].notna() → ambil hanya baris yang nilai major01-nya tidak kosong.
#
# [['student_id', 'name', 'major01', 'major02', 'project', 'final']] → pilih kolom yang ditampilkan seperti di gambar.
#
# display() → biar tabelnya rapi (jika di Jupyter/Colab).
#
# Hasilnya bakal muncul tabel dengan tiga baris (Faisal Ali, NaN, dan Khaled Majid)

# %%
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
# filter sesuai data di tabel (3 student_id)
filtered_df = df[df['student_id'].isin([211110888, 211210095, 213210082])][
    ['student_id','name','major01','major02','project','final']
]

print('filtered table:')
filtered_df
# Out:
# filtered table:
#    student_id          name  major01  major02  project  final
# 2   211210095  Ahmed Assiri    13.25     14.6    16.25   24.0

# %% [markdown]
# df['student_id'].isin([...]) → menyaring hanya baris dengan student_id tertentu.
#
# [['student_id', 'name', 'major01', 'major02', 'project', 'final']] → memilih kolom yang ingin ditampilkan.
#
# display() → menampilkan hasil tabel dengan format rapi (seperti di Jupyter/Colab).
#
# Hasilnya bakal identik seperti d

# %%
# table 1
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
tabel1 = df[df['student_id'].isin([211210095, 212110889, 213111128])][
    ['student_id','name','major01','major02','project','final']
]

print('tabel 1:')
tabel1
# Out:
# tabel 1:
#     student_id                 name  major01  major02  project  final
# 2    211210095         Ahmed Assiri    13.25     14.6    16.25   24.0
# 10   213111128  Abdelhalim Mohanned    15.52     11.3    13.30   14.0

# %%
# tabel 2
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
tabel2 = df[df['student_id'].isin([211110888, 211210095, 213210082])][
    ['student_id','name','major01','project']
]

print('tabel 2:')
tabel2
# Out:
# tabel 2:
#    student_id          name  major01  project
# 2   211210095  Ahmed Assiri    13.25    16.25

# %%
# tabel 3
df = pd.read_csv('/content/drive/MyDrive/student_scores.csv')
df = df.dropna()
tabel3 = df[df['student_id'].isin([211110888, 213210082])][
    ['student_id','name']
]

print('tabel 3:')
tabel3
# Out:
# tabel 3:
# Empty DataFrame
# Columns: [student_id, name]
# Index: []

# %%
# Tabel 3: student_id, name
tabel3 = df[df['student_id'].isin([211110888, 213210082])][
    ['student_id', 'name']
]

print("Tabel 3:")
display(tabel3)
# Out:
# Tabel 3:
# Empty DataFrame
# Columns: [student_id, name]
# Index: []
